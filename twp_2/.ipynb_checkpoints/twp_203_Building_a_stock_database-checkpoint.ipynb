# %% [markdown]
# # Building a stock price database#
#
# In this notebook we will download historic data for all SPY symbols and build a database of prices. For this we will use HDF5 format which is supported by pandas.
#
# As an example let's take the [SPY components](https://www.spdrs.com/product/fund.seam?ticker=SPY). The excel sheet can be downloaded from [here](https://www.spdrs.com/site-content/xls/SPY_All_Holdings.xls?fund=SPY&docname=All+Holdings&onyx_code1=1286&onyx_code2=1700), or even better, download it automatically. The following piece of code will do just that, unless you're behind a proxy.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import urllib.request, urllib.parse, urllib.error
import os

fName = 'data/spy_holdings.xls'

if not os.path.exists('data'): os.mkdir('data') # create data directory if it does not exist
urllib.request.urlretrieve ("https://www.spdrs.com/site-content/xls/SPY_All_Holdings.xls?fund=SPY&docname=All+Holdings&onyx_code1=1286&onyx_code2=1700",
                             fName) # download xls file and save it to data directory
# Out:
# ('data/spy_holdings.xls', <http.client.HTTPMessage at 0x25c9f9583c8>)

# %% [markdown]
# Now we'll read the symbols from xls file. I have already taken a look at it and know that the data is contained in rows 5-505. The column names are *Name,Ticker,Weight,Sector,Shares Held*
# We'll now parse this file in a similar way we parsed a csv file in the previous excersise, putting the relevant data to a `DataFrame`

# %%
import xlrd # module for excel file reading
import pandas as pd


wb = xlrd.open_workbook(fName) # open xls file, create a workbook
sh = wb.sheet_by_index(0) # select first sheet


data = {'name':[], 'symbol':[], 'weight':[],'sector':[]}
for rowNr  in range(5,505): # cycle through the rows
    v = sh.row_values(rowNr) # get all row values
    data['name'].append(v[0])
    data['symbol'].append(v[1]) # symbol is in the second column, append it to the list
    data['weight'].append(float(v[2]))
    data['sector'].append(v[3])
  
holdings = pd.DataFrame(data)    
holdings.head(10) # show first 10 rows
# Out:
#                               name                      sector symbol  \
# 0            Microsoft Corporation      Information Technology   MSFT
# 1          Exxon Mobil Corporation                      Energy    XOM
# 2  Berkshire Hathaway Inc. Class B                  Financials  BRK.B
# 3                Johnson & Johnson                 Health Care    JNJ
# 4             JPMorgan Chase & Co.                  Financials    JPM
# 5                  Amazon.com Inc.      Consumer Discretionary   AMZN
# 6         General Electric Company                 Industrials     GE
# 7            Facebook Inc. Class A      Information Technology     FB
# 8                        AT&T Inc.  Telecommunication Services      T
# 9            Wells Fargo & Company                  Financials    WFC
#
#      weight
# 0  2.534096
# 1  1.920182
# 2  1.616282
# 3  1.609118
# 4  1.592300
# 5  1.558876
# 6  1.458060
# 7  1.429154
# 8  1.334286
# 9  1.293132

# %% [markdown]
# A DataFrame can be saved to excel directly by using .to_excel()

# %%
#holdings.to_excel('holdings.xls')

# %% [markdown]
# Now we've got all 500 symbols.
#
# There is acutally a function in the TWP library that executes the process above:

# %%
import tradingWithPython.lib.extra as extra
holdings = extra.getSpyHoldings('data') # twp library contains a function to get current list of SPY holdings
# Out:
# File found, skipping download

# %% [markdown]
# A `DataFrame` can be used in to select data, providing basic database functionality. I will be working with the Health Care sector, but you can download all the symbols if you like.

# %%
# select only Health Care sector
healthCare = holdings[holdings['sector'] == 'Health Care']
healthCare
# Out:
#                                            name       sector symbol    weight
# 3                             Johnson & Johnson  Health Care    JNJ  1.609118
# 16                                  Pfizer Inc.  Health Care    PFE  1.008469
# 21                             Merck & Co. Inc.  Health Care    MRK  0.839974
# 24              UnitedHealth Group Incorporated  Health Care    UNH  0.787615
# 33                                   Amgen Inc.  Health Care   AMGN  0.558756
# 37                                  AbbVie Inc.  Health Care   ABBV  0.510978
# 40                                Medtronic plc  Health Care    MDT  0.505449
# 41                 Bristol-Myers Squibb Company  Health Care    BMY  0.503091
# 42                         Gilead Sciences Inc.  Health Care   GILD  0.500885
# 44                          Celgene Corporation  Health Care   CELG  0.460632
# 58                                 Allergan plc  Health Care    AGN  0.373202
# 61                        Eli Lilly and Company  Health Care    LLY  0.364998
# 73                                  Biogen Inc.  Health Care   BIIB  0.315724
# 80                          Abbott Laboratories  Health Care    ABT  0.288775
# 82                Thermo Fisher Scientific Inc.  Health Care    TMO  0.285224
# 99                          Danaher Corporation  Health Care    DHR  0.244651
# 111                                  Aetna Inc.  Health Care    AET  0.222009
# 112             Express Scripts Holding Company  Health Care   ESRX  0.216689
# 124                                 Anthem Inc.  Health Care   ANTM  0.195907
# 126                         Stryker Corporation  Health Care    SYK  0.190699
# 130                Becton Dickinson and Company  Health Care    BDX  0.180748
# 131                           Cigna Corporation  Health Care     CI  0.180508
# 143                        McKesson Corporation  Health Care    MCK  0.164188
# 157                                 Humana Inc.  Health Care    HUM  0.151615
# 160               Boston Scientific Corporation  Health Care    BSX  0.150022
# 171              Regeneron Pharmaceuticals Inc.  Health Care   REGN  0.140905
# 179                Alexion Pharmaceuticals Inc.  Health Care   ALXN  0.135917
# 180                         Zoetis Inc. Class A  Health Care    ZTS  0.135487
# 193                     Intuitive Surgical Inc.  Health Care   ISRG  0.125210
# 198                        Cardinal Health Inc.  Health Care    CAH  0.120927
# 207                       St. Jude Medical Inc.  Health Care    STJ  0.116185
# 215                           HCA Holdings Inc.  Health Care    HCA  0.112516
# 220                   Baxter International Inc.  Health Care    BAX  0.110794
# 228                 Zimmer Biomet Holdings Inc.  Health Care    ZBH  0.103450
# 237            Edwards Lifesciences Corporation  Health Care     EW  0.099227
# 244                               Illumina Inc.  Health Care   ILMN  0.095807
# 255         Vertex Pharmaceuticals Incorporated  Health Care   VRTX  0.091455
# 264                                  Mylan N.V.  Health Care    MYL  0.088143
# 275                             C. R. Bard Inc.  Health Care    BCR  0.082094
# 286                   Agilent Technologies Inc.  Health Care      A  0.076452
# 294                          Cerner Corporation  Health Care   CERN  0.074351
# 307                        DENTSPLY SIRONA Inc.  Health Care   XRAY  0.071248
# 321               AmerisourceBergen Corporation  Health Care    ABC  0.067404
# 323  Laboratory Corporation of America Holdings  Health Care     LH  0.066969
# 327              Quest Diagnostics Incorporated  Health Care    DGX  0.066162
# 338                           Henry Schein Inc.  Health Care   HSIC  0.063877
# 344                             Perrigo Co. Plc  Health Care   PRGO  0.061894
# 360           Mettler-Toledo International Inc.  Health Care    MTD  0.056697
# 361                                Hologic Inc.  Health Care   HOLX  0.056652
# 362                          Waters Corporation  Health Care    WAT  0.055787
# 373                                 DaVita Inc.  Health Care    DVA  0.054196
# 391                         Centene Corporation  Health Care    CNC  0.050811
# 401      Universal Health Services Inc. Class B  Health Care    UHS  0.048716
# 424                 Varian Medical Systems Inc.  Health Care    VAR  0.043642
# 426                       Cooper Companies Inc.  Health Care    COO  0.043389
# 443                   Envision Healthcare Corp.  Health Care   EVHC  0.039166
# 472                            Mallinckrodt Plc  Health Care    MNK  0.029579
# 474                            PerkinElmer Inc.  Health Care    PKI  0.029269
# 498                    Patterson Companies Inc.  Health Care   PDCO  0.017200
# 499                      Endo International Plc  Health Care   ENDP  0.016174

# %% [markdown]
# ## Download historic data##

# %%
symbols = healthCare['symbol'].tolist()
print(symbols)
# Out:
# ['JNJ', 'PFE', 'MRK', 'UNH', 'AMGN', 'ABBV', 'MDT', 'BMY', 'GILD', 'CELG', 'AGN', 'LLY', 'BIIB', 'ABT', 'TMO', 'DHR', 'AET', 'ESRX', 'ANTM', 'SYK', 'BDX', 'CI', 'MCK', 'HUM', 'BSX', 'REGN', 'ALXN', 'ZTS', 'ISRG', 'CAH', 'STJ', 'HCA', 'BAX', 'ZBH', 'EW', 'ILMN', 'VRTX', 'MYL', 'BCR', 'A', 'CERN', 'XRAY', 'ABC', 'LH', 'DGX', 'HSIC', 'PRGO', 'MTD', 'HOLX', 'WAT', 'DVA', 'CNC', 'UHS', 'VAR', 'COO', 'EVHC', 'MNK', 'PKI', 'PDCO', 'ENDP']

# %% [markdown]
# these are the Health Care sector symbols. Don't worry about the 'u' berore a symbol, it only indicates that this is a unicode string.
# We can now download data from Yahoo with the `yahooFinance` module

# %%
import tradingWithPython.lib.yahooFinance as yf


quote = yf.getQuote(symbols) # get current quote
quote.head(10) # show 10 first rows
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The `HistData` class of `yahooFinance` provides an easy way of downloading multiple prices. Please take a look at the code to see how it works.
# All OHLC prices are saved for each symbol in a [`Panel`](http://pandas.pydata.org/pandas-docs/version/0.10.1/dsintro.html#panel) container.
# For your convenience, the OHLC prices  are automatically adjusted for splits and dividends using the

# %%
hData = yf.HistData() # create HistData class
hData.downloadData(symbols) # download symbols
# Out:
#  [*********************100%***********************]  60 of 60 complete

# %% [markdown]
# to get the prices from `HistData`, you can use the `getDataFrame` method with *close, open, high or low*:

# %%
# plot the prices on a log scale
C = hData.getDataFrame('close') # getDataFrame of closing prices
figsize(15,8)
C.plot(grid=True, legend=False) # turning off the legend is wise here as it would take quite some space
xlabel('date')
ylabel('price [$]')

# %% [markdown]
# ## Save data to file##

# %% [markdown]
# `HistData` class can save data to HDF5 for later use:

# %%
hData.save('data/healthcare.h5')
# Out:
# ('Saving data to', 'data/healthcare.h5')

# %% [markdown]
# ## Load data from file##
#
# HDF5 data container is great for saving large datasets, because of its fast loading speed.
# Reload data from file:

# %%
hData2 = yf.HistData() # new hist data class
hData2.load('data/healthcare.h5') # load from file

# %% [markdown]
# If you would like to update all the data, just call the `.downloadData()` method without parameters:

# %%
hData2.downloadData() # download all symbols
hData.save('data/healthcare.h5') # save again to disk
# Out:
#  [*********************100%***********************]  56 of 56 complete('Saving data to', 'data/healthcare.h5')

# %% [markdown]
# Now we have got a set of prices ready to play with.
