# %%
import matplotlib as mpl
import tradingWithPython as twp
import pandas as pd
import numpy as np

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
twp.extra.setNotebookStyle()

# %%
twp.extra.setNotebookStyle()

# %%
hd = twp.yahooFinance.getHistoricData('SPY')
hist = hd['adj_close']
# Out:
# Got 6012 days of data

# %%
print(hd.head(20))
# Out:
#             adj_close  close   high    low   open    volume
# 1993-01-29      28.17  43.94  43.97  43.75  43.97  1.00e+06
# 1993-02-01      28.37  44.25  44.25  43.97  43.97  4.80e+05
# 1993-02-02      28.43  44.34  44.38  44.12  44.22  2.01e+05
# 1993-02-03      28.73  44.81  44.84  44.38  44.41  5.29e+05
# 1993-02-04      28.85  45.00  45.09  44.47  44.97  5.32e+05
# ...               ...    ...    ...    ...    ...       ...
# 1993-02-22      28.03  43.72  43.78  43.56  43.69  5.14e+05
# 1993-02-23      28.01  43.69  43.88  43.47  43.84  3.74e+05
# 1993-02-24      28.37  44.25  44.25  43.72  43.72  2.63e+04
# 1993-02-25      28.43  44.34  44.38  44.12  44.22  4.45e+04
# 1993-02-26      28.47  44.41  44.44  44.19  44.44  6.62e+04
#
# [20 rows x 6 columns]

# %%
mpl.style.use('ggplot')
figsize(10,8)
hist.plot()
plt.grid(True)
figure() 
dr = hist.pct_change().plot()
