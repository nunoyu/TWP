# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import tradingWithPython as twp
import tradingWithPython.lib.yahooFinance as yf
from tradingWithPython import sharpe
import pandas as pd 
twp.extra.setNotebookStyle()

# %%
ohlc = yf.getHistoricData('XLP')[['open','high','low','close']] #直接调整所需要的列，而且是多列
# Out:
# Got 4550 days of data

# %%
ohlc.head()
# Out:
#              open   high    low  close
# 1998-12-22  25.88  26.53  25.88  26.50
# 1998-12-23  26.80  28.80  26.69  27.14
# 1998-12-24  27.14  27.14  27.00  27.09
# 1998-12-28  27.14  27.16  26.81  26.94
# 1998-12-29  26.95  27.56  25.98  27.53

# %%
ohlc.plot()

# %% [markdown]
# 交易策略，昨日跌0.25%，今日开盘跌0.1以上。这里是针对spy指数的策略。

# %%
stratData = pd.DataFrame(index=ohlc.index) #建立与历史数据index相同的数据
stratData['cc'] = 100 * ohlc['close'].pct_change() #每日收盘与前日收盘的涨跌幅
stratData['co'] = 100 * (ohlc['open'] / ohlc['close'].shift(1) -1)#昨日收盘于今日开盘涨跌幅
stratData['oc'] = 100 * (ohlc['close'] / ohlc['open'] - 1) #当天涨跌幅
stratData.plot()

# %%
stratData.cumsum().plot()

# %%
idx = (stratData['cc']<-0.25).shift(1) & (stratData['co']<-0.1) #直接获得一个series,index与stratData一致，而且是前一天的跌幅小于0.25
#shift(1)表示前一天满足条件

# %%
idx #获得布尔值序列
# Out:
# 1998-12-22    False
# 1998-12-23    False
# 1998-12-24    False
# 1998-12-28    False
# 1998-12-29    False
#               ...
# 2017-01-17    False
# 2017-01-18    False
# 2017-01-19    False
# 2017-01-20    False
# 2017-01-23    False
# dtype: bool

# %%
idx[0] = False

# %%
type(idx)
# Out:
# pandas.core.series.Series

# %%
stratData['goLong'] = idx
stratData['pnl'] = 0. #初始仓位为0,一定记得加上小数点
stratData.ix[idx, 'pnl'] = stratData.ix[idx, 'oc']
#如果某日的idx是true，也即附和买入条件，那么当日的pnl就等于当日收盘比开盘涨幅。因为策略是当日收盘清仓。 
#对于不每日balance的策略，pnl不能这么算。需要用backtest方法来计算。例如早先的一些均线投资回测策略。bt.pnl()
stratData.tail(20)
# Out:
#               cc    co    oc goLong  pnl
# 2016-12-22 -0.15 -0.12 -0.04  False  0.0
# 2016-12-23  0.19 -0.06  0.25  False  0.0
# 2016-12-27 -0.02 -0.08  0.06  False  0.0
# 2016-12-28 -0.61 -0.08 -0.54  False  0.0
# 2016-12-29  0.46  0.06  0.41  False  0.0
# ...          ...   ...   ...    ...  ...
# 2017-01-17  1.42  0.08  1.34  False  0.0
# 2017-01-18  0.34 -0.10  0.44  False  0.0
# 2017-01-19 -0.36 -0.11 -0.25  False  0.0
# 2017-01-20  0.65  0.48  0.17  False  0.0
# 2017-01-23 -0.04  0.00 -0.04  False  0.0
#
# [20 rows x 5 columns]

# %%
sharpe(stratData['pnl'])
# Out:
# 1.1132811027836282

# %%
stratData['pnl'].cumsum().plot(grid=True)

# %%
def backtest(ohlc, ccThresh=-0.25, coThresh=-0.1):
    '''
    function to backtest the strategy of percentage change in stock price of the current day & a day before
    
    parameters
    ==========
    ohlc: DataFrame
        historial open, high, low, close price 
    ccThresh: float
        percentage decline one day before
    coThresh: float
        percentage decline of current day's open relative to the close of one day before
    '''
    stratData = pd.DataFrame(index=ohlc.index)
    stratData['cc'] = 100*ohlc['close'].pct_change() # close-to-close change in %
    stratData['co'] = 100*(ohlc['open']/ohlc['close'].shift(1)-1) # previous close to open change in %
    stratData['oc'] = 100*(ohlc['close']/ohlc['open']-1) # open to close change in %

    idx = (stratData['cc']<ccThresh).shift(1) & (stratData['co']<coThresh)
    idx[0] = False
    
    stratData['goLong'] = idx
    stratData['pnl'] = 0. # init pnl column with zeros (Watch out: if initialized with integer value (0), an error will pop later on)
    stratData.ix[idx,'pnl'] = stratData.ix[idx, 'oc'] # set pnl column values to daily return wehere 'goLong' is true
    
    return stratData['pnl']

# %%
pnl = backtest(ohlc)
pnl.cumsum().plot()
print('Sharpe:', sharpe(pnl))
# Out:
# Sharpe: 1.11328110278

# %%
from tradingWithPython.lib.extra import ProgressBar
ccThresh = np.linspace(-1, 1, 30)
coThresh = np.linspace(-0.5, 0.5, 30)
pbar = ProgressBar(len(ccThresh)-1)
SH = np.zeros((len(ccThresh), len(coThresh)))
for i, cc in enumerate(ccThresh):
    pbar.animate(i)
    for j, co in enumerate(coThresh):
        pnl = backtest(ohlc, cc, co)
        SH[i, j] = sharpe(pnl)
pcolor(coThresh, ccThresh, SH)
i,j = np.unravel_index(SH.argmax(), SH.shape)
SH[i,j]
print('Optimum CC %.2f' % ccThresh[i])
print('Optimum CO %.2f' % coThresh[j])
# Out:
#  [*********************100%***********************]  29 of 29 completeOptimum CC 0.03
# Optimum CO 0.12

# %%
pnl = backtest(ohlc, ccThresh=0.03, coThresh=0.12) #使用最优参数进行回测
pnl.cumsum().plot()

# %%
#修改一下，看看这个分段方式要干什么
#看来是从nTrain起，逐步右移，Trest无缝覆盖。最后留下一段nTotal不要了。
#为什么最后一段不要了还搞不清楚
def generateFWDtest(data, nTrain=250, nTest=50):
    '''
    Walk Forward Generator. The application will return two series of datas, the first one is for optimazation, and the the second for backtest. 
    Parameters:
    ===========
    data: pd.DataFrame
        complete dataset of stock pricein the overall period
    nTrain: int
        # of days in dataset for optimazation
    nTest: int
        # of days in dataset for backtest
    '''
    nTotal = nTrain + nTest
    for tp in range(nTrain, len(data)-nTotal, nTest): 
        print(tp)

# %%
generateFWDtest(ohlc)
# Out:
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200

# %%
len(ohlc)
# Out:
# 4550

# %%
def generateFWD(data, nTrain=250, nTest=50):
    '''
    Walk Forward Generator. The application will return two series of datas, the first one is for optimazation, and the the second for backtest. 
    Parameters:
    ===========
    data: pd.DataFrame
        complete dataset of stock pricein the overall period
    nTrain: int
        # of days in dataset for optimazation
    nTest: int
        # of days in dataset for backtest
    '''
    nTotal = nTrain + nTest
    for tp in range(nTrain, len(data)-nTotal, nTest): #tp is the boundary of testpoint which split the dataset in in the sample & out of sample
                                                      #因为tp是临界点，所以左侧留出至少nTrain个位置。序列的右端点为数据总长，减去需要数据总长。
                                                      #这个设定搞不太懂。步长应该是随意设定的。
                                                      #个人感觉，右侧限制因该是一个错误。理想的是len(data)-nTest。这样合理，右侧留出一个测试段。
        yield(data.iloc[tp-nTrain:tp,:], data.iloc[tp:tp+nTest], tp) #iloc用来序号定位。如果tp是临界点标号，则讲得通。
                                                                     #返回三个值，最后一个tp,即分界点编号

# %%
def optimize(data):
    '''
    make a series of attempts to find out the optimal parameters for the strategy
    Parameter:
    =========
    data: pd.DataFrame
          dataset of stock price
    '''
    from tradingWithPython.lib.extra import ProgressBar
    ccThresh = np.linspace(-1, 1, 30)
    coThresh = np.linspace(-0.5, 0.5, 30)
    pbar = ProgressBar(len(ccThresh)-1)
    SH = np.zeros((len(ccThresh), len(coThresh)))
    for i, cc in enumerate(ccThresh):
        pbar.animate(i)
        for j, co in enumerate(coThresh):
            pnl = backtest(data, cc, co)
            SH[i, j] = sharpe(pnl)
    i,j = np.unravel_index(SH.argmax(), SH.shape)
    SH[i, j]
    return ccThresh[i], coThresh[j]

# %%
nTest = 250 #重新设定测试周期，默认的是50
pnl = [] #建立一个list， 用来记录回测结果结果
