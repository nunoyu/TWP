# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import tradingWithPython as twp
import tradingWithPython.lib.yahooFinance as yf
import pandas as pd
twp.extra.setNotebookStyle()

# %% [markdown]
# # 获取XLE能源指数的成分股名单

# %%
import urllib.request, urllib.parse, urllib.error

# %%
urllib.request.urlretrieve('http://www.sectorspdr.com/sectorspdr/IDCO.Client.Spdrs.Holdings/Export/ExportCsv?symbol=xle', 'xle.csv')
#读取网络csv，然后保存为xle.csv
# Out:
# ('xle.csv', <http.client.HTTPMessage at 0x1304a7bc518>)

# %%
xleComponents = pd.read_csv('xle.csv', sep=',', skiprows=1) #读取csv
xleComponents
# Out:
#    Symbol                Company Name Index Weight    Last  Change %Change  \
# 0     XOM            Exxon Mobil Corp       15.76%   85.34    0.25  +0.29%
# 1     CVX                Chevron Corp       14.91%  117.24    0.87  +0.75%
# 2     SLB            Schlumberger Ltd        8.19%   85.51    0.93  +1.10%
# 3     EOG               EOG Resources        4.82%  103.90    0.22  +0.21%
# 4     PXD   Pioneer Natural Resources        4.57%  180.27   -0.48  -0.27%
# 5     HAL              Halliburton Co        3.92%   57.41    0.79  +1.40%
# 6     COP              ConocoPhillips        3.06%   50.69    0.42  +0.84%
# 7     APC     Anadarko Petroleum Corp        3.03%   70.67   -0.51  -0.72%
# 8     OXY        Occidental Petroleum        3.00%   68.13    0.26  +0.38%
# 9     KMI           Kinder Morgan Inc        2.86%   22.60   -0.02  -0.09%
# 10    VLO          Valero Energy Corp        2.85%   68.33    0.47  +0.69%
# 11     SE         Spectra Energy Corp        2.69%   43.31    0.55  +1.29%
# 12    PSX                 Phillips 66        2.48%   85.00    0.81  +0.96%
# 13    BHI            Baker Hughes Inc        2.35%   63.60    0.92  +1.47%
# 14    WMB  The Williams Companies Inc        2.19%   28.81    0.33  +1.16%
# 15    TSO                 Tesoro Corp        1.99%   82.03    0.05  +0.06%
# 16    FTI              TechnipFMC Ltd        1.97%   35.27    1.06  +3.10%
# 17    DVN           Devon Energy Corp        1.85%   46.46   -0.13  -0.28%
# 18    APA                 Apache Corp        1.77%   61.43    0.47  +0.77%
# 19    MPC    Marathon Petroleum Corp.        1.73%   49.67   -0.42  -0.84%
# 20    COG           Cabot Oil & Gas A        1.53%   22.93   -0.04  -0.17%
# 21    NBL            Noble Energy Inc        1.53%   39.79   -0.24  -0.60%
# 22    CXO        Concho Resources Inc        1.38%  143.12    4.08  +2.93%
# 23    NOV  National Oilwell Varco Inc        1.26%   39.72    0.68  +1.74%
# 24    HES                   Hess Corp        1.23%   56.46   -1.06  -1.84%
# 25    MRO           Marathon Oil Corp        1.16%   17.75    0.05  +0.28%
# 26    XEC           Cimarex Energy Co        0.88%  139.92    1.62  +1.17%
# 27    OKE                   ONEOK Inc        0.77%   55.55   -0.73  -1.30%
# 28    EQT             EQT Corporation        0.73%   64.12    0.09  +0.14%
# 29    RRC        Range Resources Corp        0.66%   33.83   -0.23  -0.68%
# 30     HP       Helmerich & Payne Inc        0.58%   81.11    1.20  +1.50%
# 31    NFX     Newfield Exploration Co        0.55%   42.50    0.08  +0.19%
# 32    CHK      Chesapeake Energy Corp        0.47%    7.13    0.22  +3.18%
# 33    MUR             Murphy Oil Corp        0.47%   32.18    0.22  +0.69%
# 34    SWN      Southwestern Energy Co        0.40%    9.61    0.11  +1.16%
# 35    RIG              Transocean Ltd        0.39%   15.30    0.38  +2.55%
#
#       Volume    52 Week Range  Unnamed: 8
# 0     9.58 M    73.55 - 95.55         NaN
# 1     5.28 M   79.85 - 119.00         NaN
# 2     5.94 M    63.42 - 87.84         NaN
# 3     2.80 M   62.29 - 109.37         NaN
# 4     1.43 M  105.22 - 195.00         NaN
# 5     9.84 M    27.96 - 57.70         NaN
# 6     5.99 M    31.05 - 53.17         NaN
# 7     3.59 M    32.25 - 73.33         NaN
# 8     6.15 M    62.14 - 78.48         NaN
# 9    19.07 M    13.26 - 23.36         NaN
# 10    4.61 M    46.88 - 71.40         NaN
# 11    3.31 M    25.74 - 44.00         NaN
# 12    1.71 M    71.74 - 90.87         NaN
# 13    3.12 M    38.16 - 68.59         NaN
# 14    7.55 M    10.22 - 32.69         NaN
# 15    1.82 M    67.80 - 93.50         NaN
# 16    6.11 M    33.17 - 34.65         NaN
# 17    4.99 M    18.07 - 50.69         NaN
# 18    3.91 M    33.23 - 69.00         NaN
# 19    7.58 M    29.24 - 54.59         NaN
# 20    4.16 M    18.48 - 26.74         NaN
# 21    5.35 M    26.71 - 42.03         NaN
# 22    1.78 M   80.70 - 147.55         NaN
# 23    2.42 M    25.74 - 43.63         NaN
# 24    6.20 M    34.02 - 65.56         NaN
# 25    8.05 M     6.52 - 19.28         NaN
# 26  915.11 K   74.77 - 146.96         NaN
# 27    2.73 M    18.88 - 59.47         NaN
# 28  962.76 K    54.22 - 80.61         NaN
# 29    3.51 M    21.69 - 46.96         NaN
# 30    2.04 M    44.05 - 85.78         NaN
# 31    1.61 M    20.84 - 50.00         NaN
# 32   48.50 M      1.50 - 8.20         NaN
# 33    3.37 M    15.23 - 37.48         NaN
# 34   11.45 M     5.30 - 15.59         NaN
# 35   16.70 M     7.67 - 16.66         NaN

# %%
symbols = xleComponents['Symbol'].tolist() #将dataframe的某lie,也就是series变成list
symbols.append('XLE') #把指数自身也加进去

# %%
hData = yf.HistData() #建立可以获取多股票数据的数据对象
hData.startDate = (2009,1,1)
hData.downloadData(symbols)
# Out:
#  [*********************100%***********************]  37 of 37 complete

# %%
C = hData.getDataFrame('close')[:-250]
C = C.dropna(axis=1)
C.plot(legend=False)
print('Last dataset date:' , C.index[-1])
